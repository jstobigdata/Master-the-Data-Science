# %% [markdown]
# # 03. Indexing and Slicing the DataFrames

# %% [markdown]
# There are various ways to select the rows and columns of a dataframe or Series.
#
# - Select the rows from a dataframe
# - Select columns from a dataframe
# - Select subsets of dataframes

# %% [markdown]
# #### Import the Pandas and NumPy Libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# #### Load the data

# %%
df = pd.read_csv('./data/Company.csv')
df
# Out:
#       EmployeeID birthdate_key  age         city_name        department  \
# 0           1318      1/3/1954   61         Vancouver         Executive
# 1           1319      1/3/1957   58         Vancouver         Executive
# 2           1320      1/2/1955   60         Vancouver         Executive
# 3           1321      1/2/1959   56         Vancouver         Executive
# 4           1322      1/9/1958   57         Vancouver         Executive
# ...          ...           ...  ...               ...               ...
# 6279        8036      8/9/1992   23  New Westminister  Customer Service
# 6280        8181     9/26/1993   22     Prince George  Customer Service
# 6281        8223     2/11/1994   21             Trail  Customer Service
# 6282        8226     2/16/1994   21          Victoria  Customer Service
# 6283        8264     6/13/1994   21         Vancouver  Customer Service
#
#                job_title gender
# 0                    CEO      M
# 1              VP Stores      F
# 2          Legal Counsel      F
# 3     VP Human Resources      M
# 4             VP Finance      M
# ...                  ...    ...
# 6279             Cashier      F
# 6280             Cashier      M
# 6281             Cashier      M
# 6282             Cashier      F
# 6283             Cashier      F
#
# [6284 rows x 7 columns]

# %%
df.head()
# Out:
#    EmployeeID birthdate_key  age  city_name department           job_title  \
# 0        1318      1/3/1954   61  Vancouver  Executive                 CEO
# 1        1319      1/3/1957   58  Vancouver  Executive           VP Stores
# 2        1320      1/2/1955   60  Vancouver  Executive       Legal Counsel
# 3        1321      1/2/1959   56  Vancouver  Executive  VP Human Resources
# 4        1322      1/9/1958   57  Vancouver  Executive          VP Finance
#
#   gender
# 0      M
# 1      F
# 2      F
# 3      M
# 4      M

# %% [markdown]
# ______________

# %% [markdown]
# ## 1. The Column index and row index
#
# - one or more columns from a dataframe selected using the following commands:
#     - `df['column_name']` or `df.column_name`: It returns a series
#     - `df[['col_x', 'col_y']]`: It returns a dataframe
# - One or more rows can be selected using the indexs:
#     - `df[2:5]`: Returns dataframe of index 2, 3, 4 - The DataFrame indexing operator selects rows and can do so by integer location or by index label.

# %% [markdown]
# ### 1. Column index

# %%
df['gender'].head(10)
# Out:
# 0    M
# 1    F
# 2    F
# 3    M
# 4    M
# 5    M
# 6    F
# 7    F
# 8    F
# 9    F
# Name: gender, dtype: object

# %%
df['gender'].unique()
# Out:
# array(['M', 'F'], dtype=object)

# %%
df[['EmployeeID', 'gender']]
# Out:
#       EmployeeID gender
# 0           1318      M
# 1           1319      F
# 2           1320      F
# 3           1321      M
# 4           1322      M
# ...          ...    ...
# 6279        8036      F
# 6280        8181      M
# 6281        8223      M
# 6282        8226      F
# 6283        8264      F
#
# [6284 rows x 2 columns]

# %% [markdown]
# ### 2. row index

# %%
df.head()
# Out:
#    EmployeeID birthdate_key  age  city_name department           job_title  \
# 0        1318      1/3/1954   61  Vancouver  Executive                 CEO
# 1        1319      1/3/1957   58  Vancouver  Executive           VP Stores
# 2        1320      1/2/1955   60  Vancouver  Executive       Legal Counsel
# 3        1321      1/2/1959   56  Vancouver  Executive  VP Human Resources
# 4        1322      1/9/1958   57  Vancouver  Executive          VP Finance
#
#   gender
# 0      M
# 1      F
# 2      F
# 3      M
# 4      M

# %%
df[2:5]
# Out:
#    EmployeeID birthdate_key  age  city_name department           job_title  \
# 2        1320      1/2/1955   60  Vancouver  Executive       Legal Counsel
# 3        1321      1/2/1959   56  Vancouver  Executive  VP Human Resources
# 4        1322      1/9/1958   57  Vancouver  Executive          VP Finance
#
#   gender
# 2      F
# 3      M
# 4      M

# %% [markdown]
# _____________

# %% [markdown]
# ## 2. `loc` and `iloc` index

# %% [markdown]
# ### 1. loc indexer
# - Access a group of rows and columns by label(s) or a boolean array from a DataFrame.
# - Used in slicing of data from DataFrame.
# - `loc[]` is a primarily label based data selecting method, means we have to pass the name of the row and column.
# - Syntax: `dataframe.loc[[list_of_row_labels]`, `[list_of_column_labels]]`

# %%
df_2 = df.set_index('EmployeeID')
df_2
# Out:
#            birthdate_key  age         city_name        department  \
# EmployeeID
# 1318            1/3/1954   61         Vancouver         Executive
# 1319            1/3/1957   58         Vancouver         Executive
# 1320            1/2/1955   60         Vancouver         Executive
# 1321            1/2/1959   56         Vancouver         Executive
# 1322            1/9/1958   57         Vancouver         Executive
# ...                  ...  ...               ...               ...
# 8036            8/9/1992   23  New Westminister  Customer Service
# 8181           9/26/1993   22     Prince George  Customer Service
# 8223           2/11/1994   21             Trail  Customer Service
# 8226           2/16/1994   21          Victoria  Customer Service
# 8264           6/13/1994   21         Vancouver  Customer Service
#
#                      job_title gender
# EmployeeID
# 1318                       CEO      M
# 1319                 VP Stores      F
# 1320             Legal Counsel      F
# 1321        VP Human Resources      M
# 1322                VP Finance      M
# ...                        ...    ...
# 8036                   Cashier      F
# 8181                   Cashier      M
# 8223                   Cashier      M
# 8226                   Cashier      F
# 8264                   Cashier      F
#
# [6284 rows x 6 columns]

# %%
s = df_2.loc[1332]
print(s)
type(s)
# Out:
# birthdate_key                           2/5/1955
# age                                           60
# city_name                              Vancouver
# department                             Executive
# job_title        Exec Assistant, Human Resources
# gender                                         F
# Name: 1332, dtype: object
# pandas.core.series.Series

# %%
df_3 = df_2.loc[[1332, 8223]]
df_3
type(df_3)
# Out:
# pandas.core.frame.DataFrame

# %%
df_2.loc[[1332, 8223], ['age', 'department']]
# Out:
#             age        department
# EmployeeID
# 1332         60         Executive
# 8223         21  Customer Service

# %%
df_2.loc[(df_2.age > 55)]
# Out:
#            birthdate_key  age        city_name department           job_title  \
# EmployeeID
# 1318            1/3/1954   61        Vancouver  Executive                 CEO
# 1319            1/3/1957   58        Vancouver  Executive           VP Stores
# 1320            1/2/1955   60        Vancouver  Executive       Legal Counsel
# 1321            1/2/1959   56        Vancouver  Executive  VP Human Resources
# 1322            1/9/1958   57        Vancouver  Executive          VP Finance
# ...                  ...  ...              ...        ...                 ...
# 4434          12/15/1946   69        Vancouver      Meats         Meat Cutter
# 4442          12/22/1946   69        Vancouver      Meats         Meat Cutter
# 4445          12/26/1946   69  New Westminster    Produce       Produce Clerk
# 4448          12/27/1946   69         Kamloops     Bakery               Baker
# 4450          12/28/1946   69  New Westminster    Produce       Produce Clerk
#
#            gender
# EmployeeID
# 1318            M
# 1319            F
# 1320            F
# 1321            M
# 1322            M
# ...           ...
# 4434            M
# 4442            M
# 4445            M
# 4448            M
# 4450            M
#
# [1952 rows x 6 columns]

# %% [markdown]
# ### 2. `iloc` indexer

# %% [markdown]
# - `iloc()` is a index based selecting method, means we have to pass integer index to select specific row/column.
# - `iloc()` does not accept boolean data inlike `loc()`

# %%
df_2.head()
# Out:
#            birthdate_key  age  city_name department           job_title gender
# EmployeeID
# 1318            1/3/1954   61  Vancouver  Executive                 CEO      M
# 1319            1/3/1957   58  Vancouver  Executive           VP Stores      F
# 1320            1/2/1955   60  Vancouver  Executive       Legal Counsel      F
# 1321            1/2/1959   56  Vancouver  Executive  VP Human Resources      M
# 1322            1/9/1958   57  Vancouver  Executive          VP Finance      M

# %%
df_2.iloc[[3,4,5], 0:4]
# Out:
#            birthdate_key  age  city_name department
# EmployeeID
# 1321            1/2/1959   56  Vancouver  Executive
# 1322            1/9/1958   57  Vancouver  Executive
# 1323            1/9/1962   53  Vancouver  Executive

# %%
df_2.iloc[[3,4,5], [0,1,2,3]]
#df_2.loc[[1321, 1322, 1323],['birthdate_key','age','city_name','department']]
# Out:
#            birthdate_key  age  city_name department
# EmployeeID
# 1321            1/2/1959   56  Vancouver  Executive
# 1322            1/9/1958   57  Vancouver  Executive
# 1323            1/9/1962   53  Vancouver  Executive

# %%
df_2.iloc[(df_2.age > 55).values].head()
# Out:
#            birthdate_key  age  city_name department           job_title gender
# EmployeeID
# 1318            1/3/1954   61  Vancouver  Executive                 CEO      M
# 1319            1/3/1957   58  Vancouver  Executive           VP Stores      F
# 1320            1/2/1955   60  Vancouver  Executive       Legal Counsel      F
# 1321            1/2/1959   56  Vancouver  Executive  VP Human Resources      M
# 1322            1/9/1958   57  Vancouver  Executive          VP Finance      M

# %% [markdown]
# ## 3. Query - [pd.DataFrame.query](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.query.html)

# %% [markdown]
# - Query the columns of a DataFrame with a boolean expression.
# - DataFrame.query(expr, inplace=False, **kwargs)
# - query expressions (string) incoming querymethod to query the data. The result of the expression must return **Boolean** value.

# %%
df_2.head()
# Out:
#            birthdate_key  age  city_name department           job_title gender
# EmployeeID
# 1318            1/3/1954   61  Vancouver  Executive                 CEO      M
# 1319            1/3/1957   58  Vancouver  Executive           VP Stores      F
# 1320            1/2/1955   60  Vancouver  Executive       Legal Counsel      F
# 1321            1/2/1959   56  Vancouver  Executive  VP Human Resources      M
# 1322            1/9/1958   57  Vancouver  Executive          VP Finance      M

# %%
df_2.query('(gender == "M")')
# Out:
#            birthdate_key  age      city_name        department  \
# EmployeeID
# 1318            1/3/1954   61      Vancouver         Executive
# 1321            1/2/1959   56      Vancouver         Executive
# 1322            1/9/1958   57      Vancouver         Executive
# 1323            1/9/1962   53      Vancouver         Executive
# 1334            2/6/1961   54      Vancouver         Executive
# ...                  ...  ...            ...               ...
# 6918            2/6/1984   31      Vancouver  Customer Service
# 7416           1/14/1988   27     Chilliwack  Customer Service
# 7741            4/7/1990   25        Nanaimo  Customer Service
# 8181           9/26/1993   22  Prince George  Customer Service
# 8223           2/11/1994   21          Trail  Customer Service
#
#                             job_title gender
# EmployeeID
# 1318                              CEO      M
# 1321               VP Human Resources      M
# 1322                       VP Finance      M
# 1323        Exec Assistant, VP Stores      M
# 1334          Exec Assistant, Finance      M
# ...                               ...    ...
# 6918                          Cashier      M
# 7416                          Cashier      M
# 7741                          Cashier      M
# 8181                          Cashier      M
# 8223                          Cashier      M
#
# [3006 rows x 6 columns]

# %%
sorted_df = df_2.query('(age >= age.mean())').sort_values(by='age', ascending=False)
sorted_df
# Out:
#            birthdate_key  age        city_name        department  \
# EmployeeID
# 2489           7/25/1941   74           Surrey             Meats
# 2388           4/20/1941   74  New Westminster             Meats
# 2365           3/30/1941   74            Trail             Meats
# 2360           3/26/1941   74          Nanaimo             Meats
# 2517           9/12/1941   74         Squamish             Meats
# ...                  ...  ...              ...               ...
# 5166          12/10/1969   46    Prince George            Bakery
# 5167          12/13/1969   46   West Vancouver            Bakery
# 5168          12/16/1969   46     Fort St John           Produce
# 5169          12/19/1969   46         Richmond           Produce
# 5130           9/16/1969   46        Vancouver  Customer Service
#
#                 job_title gender
# EmployeeID
# 2489          Meat Cutter      F
# 2388          Meat Cutter      F
# 2365          Meat Cutter      F
# 2360          Meat Cutter      F
# 2517          Meat Cutter      F
# ...                   ...    ...
# 5166                Baker      M
# 5167                Baker      M
# 5168        Produce Clerk      F
# 5169        Produce Clerk      F
# 5130              Cashier      F
#
# [3139 rows x 6 columns]

# %% [markdown]
# ____
# ## Assignment:
# - Load the `company.csv` DataSet
# - Sort the dataset based on age.
# - Print only the top 10 dataSets
# - Print the last 10 dataSets
# - Select the top 10 records where gender=M, department=Bakery and age is less than 50.

# %% [markdown]
# ## Recommended Readings
# - [Geeksforgeeks - Difference between iloc() and loc()](https://www.geeksforgeeks.org/difference-between-loc-and-iloc-in-pandas-dataframe/)
# - [Use loc and iloc for selecting data in Pandas](https://towardsdatascience.com/how-to-use-loc-and-iloc-for-selecting-data-in-pandas-bd09cb4c3d79)
